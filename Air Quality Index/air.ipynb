# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('AirQualityUCI.csv',sep=';',decimal=',')

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN
# 3  11.0  60.0  0.7867          NaN          NaN
# 4  11.2  59.6  0.7888          NaN          NaN

# %%
df.shape
# Out:
# (9471, 17)

# %%
df=df.iloc[:,:-2]

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %%
df.loc[[9356]]
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9356        816.0  28.5  13.1  0.5028

# %%
df=df.head(9357)

# %%
df.shape
# Out:
# (9357, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df.isin([-200]).sum(axis=0)
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
df=df.replace(-200,np.NaN)

# %%
df.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
df = df.fillna(df.mean(numeric_only=True))

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# # Forecasting

# %%
date_info=pd.to_datetime(df['Date'],dayfirst=True)
time_info=df['Time']
time_info=time_info.apply(lambda x:x.replace('.',':'))

# %%
print(date_info)
# Out:
# 0      2004-03-10
# 1      2004-03-10
# 2      2004-03-10
# 3      2004-03-10
# 4      2004-03-10
#           ...
# 9352   2005-04-04
# 9353   2005-04-04
# 9354   2005-04-04
# 9355   2005-04-04
# 9356   2005-04-04
# Name: Date, Length: 9357, dtype: datetime64[ns]

# %%
print(time_info)
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# 9356    14:00:00
# Name: Time, Length: 9357, dtype: object

# %%
date_time=pd.concat([date_info,time_info],axis=1)
date_time.head()
# Out:
#         Date      Time
# 0 2004-03-10  18:00:00
# 1 2004-03-10  19:00:00
# 2 2004-03-10  20:00:00
# 3 2004-03-10  21:00:00
# 4 2004-03-10  22:00:00

# %%
date_time['DS']=date_time['Date'].astype(str)+" "+date_time['Time'].astype(str)

# %%
date_time.head()
# Out:
#         Date      Time                   DS
# 0 2004-03-10  18:00:00  2004-03-10 18:00:00
# 1 2004-03-10  19:00:00  2004-03-10 19:00:00
# 2 2004-03-10  20:00:00  2004-03-10 20:00:00
# 3 2004-03-10  21:00:00  2004-03-10 21:00:00
# 4 2004-03-10  22:00:00  2004-03-10 22:00:00

# %%
data=pd.DataFrame()

# %%
data['ds']=pd.to_datetime(date_time['DS'])

# %%
data.head()
# Out:
#                    ds
# 0 2004-03-10 18:00:00
# 1 2004-03-10 19:00:00
# 2 2004-03-10 20:00:00
# 3 2004-03-10 21:00:00
# 4 2004-03-10 22:00:00

# %%
data['y']=df['RH']

# %%
data.shape
# Out:
# (9357, 2)

# %%
# !pip install prophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting prophet
#   Downloading prophet-1.3.0-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.15.4 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from prophet) (3.9.2)
# Requirement already satisfied: pandas>=1.0.4 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from prophet) (2.2.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.97-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: tqdm>=4.36.1 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from prophet) (4.66.5)
# Collecting importlib_resources (from prophet)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting python-dateutil<3,>=2.9.0.post0 (from holidays<1,>=0.25->prophet)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.16.0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=2.0.0->prophet) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=8 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=2.0.0->prophet) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=2.0.0->prophet) (3.1.4)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: colorama in C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Downloading prophet-1.3.0-py3-none-win_amd64.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.1 MB 12.2 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.1 MB 11.4 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.1 MB 10.3 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.1 MB 9.9 MB/s eta 0:00:01
#    --------------------------------- ------ 10.2/12.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.1 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 9.2 MB/s  0:00:01
# Downloading holidays-0.97-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 9.7 MB/s  0:00:00
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Installing collected packages: stanio, python-dateutil, importlib_resources, holidays, cmdstanpy, prophet
#
#   Attempting uninstall: python-dateutil
#
#     Found existing installation: python-dateutil 2.8.2
#
#    ------ --------------------------------- 1/6 [python-dateutil]
#     Uninstalling python-dateutil-2.8.2:
#    ------ --------------------------------- 1/6 [python-dateutil]
#       Successfully uninstalled python-dateutil-2.8.2
#    ------ --------------------------------- 1/6 [python-dateutil]
#    ------ --------------------------------- 1/6 [python-dateutil]
#    ------ --------------------------------- 1/6 [python-dateutil]
#    ------ --------------------------------- 1/6 [python-dateutil]
#    ------------- -------------------------- 2/6 [importlib_resources]
#    ------------- -------------------------- 2/6 [importlib_resources]
#    ------------- -------------------------- 2/6 [importlib_resources]
#    ------------- -------------------------- 2/6 [importlib_resources]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------------- ------------- 4/6 [cmdstanpy]
#    -------------------------- ------------- 4/6 [cmdstanpy]
#    -------------------------- ------------- 4/6 [cmdstanpy]
#    -------------------------- ------------- 4/6 [cmdstanpy]
#    -------------------------- ------------- 4/6 [cmdstanpy]
#    -------------------------- ------------- 4/6 [cmdstanpy]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    ---------------------------------------- 6/6 [prophet]
#
# Successfully installed cmdstanpy-1.3.0 holidays-0.97 importlib_resources-7.1.0 prophet-1.3.0 python-dateutil-2.9.0.post0 stanio-0.5.1
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages)

# %%
from prophet import Prophet

# %%
model=Prophet()
model.fit(data)
# Out:
# 17:10:08 - cmdstanpy - INFO - Chain [1] start processing
# 17:10:10 - cmdstanpy - INFO - Chain [1] done processing

# %%
future=model.make_future_dataframe(periods=365,freq='H')
future.tail()
# Out:
# C:\Users\Ronit Jariwala\AppData\Roaming\Python\Python311\site-packages\prophet\forecaster.py:1875: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.date_range(
#                       ds
# 9717 2005-04-19 15:00:00
# 9718 2005-04-19 16:00:00
# 9719 2005-04-19 17:00:00
# 9720 2005-04-19 18:00:00
# 9721 2005-04-19 19:00:00

# %%
forecast=model.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#                       ds       yhat  yhat_lower  yhat_upper
# 9717 2005-04-19 15:00:00  33.553257   18.958747   49.545357
# 9718 2005-04-19 16:00:00  34.036783   18.257146   49.691759
# 9719 2005-04-19 17:00:00  35.670102   21.423358   50.553341
# 9720 2005-04-19 18:00:00  38.565725   22.645293   54.099839
# 9721 2005-04-19 19:00:00  42.119927   26.104082   57.401089

# %%
fig1=model.plot(forecast)

# %%
fig2=model.plot_components(forecast)
