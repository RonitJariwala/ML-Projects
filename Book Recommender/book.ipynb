# %%
import pandas as pd
import numpy as np

# %%
books=pd.read_csv('BX-Books.csv',encoding='latin-1')
users=pd.read_csv('BX-Users.csv',encoding='latin-1')
# Out:
# C:\Users\Ronit Jariwala\AppData\Local\Temp\ipykernel_4144\2337197589.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv('BX-Books.csv',encoding='latin-1')
# C:\Users\Ronit Jariwala\AppData\Local\Temp\ipykernel_4144\2337197589.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   users=pd.read_csv('BX-Users.csv',encoding='latin-1')

# %%
books.columns
# Out:
# Index(['isbn', 'book_title', 'book_author', 'year_of_publication',
#        'publisher'],
#       dtype='object')

# %%
books.rename(columns={'book_title':'title','book_author':'author','year_of_publication':'year'},inplace=True)

# %%
books.head(2)
# Out:
#         isbn                title                author  year  \
# 0  195153448  Classical Mythology    Mark P. O. Morford  2002
# 1    2005018         Clara Callan  Richard Bruce Wright  2001
#
#                  publisher
# 0  Oxford University Press
# 1    HarperFlamingo Canada

# %%
users
# Out:
#        user_id                            Location   Age
# 0            1                  nyc, new york, usa   NaN
# 1            2           stockton, california, usa  18.0
# 2            3     moscow, yukon territory, russia   NaN
# 3            4           porto, v.n.gaia, portugal  17.0
# 4            5  farnborough, hants, united kingdom   NaN
# ...        ...                                 ...   ...
# 278854  278854               portland, oregon, usa   NaN
# 278855  278855  tacoma, washington, united kingdom  50.0
# 278856  278856           brampton, ontario, canada   NaN
# 278857  278857           knoxville, tennessee, usa   NaN
# 278858  278858                dublin, n/a, ireland   NaN
#
# [278859 rows x 3 columns]

# %%
users.rename(columns={'Location':'location','Age':'age'},inplace=True)

# %%
users.head(2)
# Out:
#   user_id                   location   age
# 0       1         nyc, new york, usa   NaN
# 1       2  stockton, california, usa  18.0

# %%
ratings=pd.read_csv('BX-Book-Ratings.csv',encoding='latin-1')
ratings
# Out:
#          user_id        isbn  rating
# 0         276725  034545104X       0
# 1         276726   155061224       5
# 2         276727   446520802       0
# 3         276729  052165615X       3
# 4         276729   521795028       6
# ...          ...         ...     ...
# 1048570   250764   451410777       0
# 1048571   250764   452264464       8
# 1048572   250764  048623715X       0
# 1048573   250764   486256588       0
# 1048574   250764   515069434       0
#
# [1048575 rows x 3 columns]

# %%
books.shape
# Out:
# (278859, 3)

# %%
users.shape
# Out:
# (278859, 3)

# %%
ratings.shape
# Out:
# (1048575, 3)

# %%
x=ratings['user_id'].value_counts()>200

# %%
y=x[x].index
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#         88793,  33145, 116122,   9856,  73681,  28634,  59727, 188951, 155916,
#         44296],
#       dtype='int64', name='user_id', length=815)

# %%
ratings=ratings[ratings['user_id'].isin(y)]
ratings.shape
# Out:
# (482728, 3)

# %%
ratings.head()
# Out:
#       user_id        isbn  rating
# 1456   277427  002542730X      10
# 1457   277427    26217457       0
# 1458   277427  003008685X       8
# 1459   277427    30615321       0
# 1460   277427    60002050       0

# %%
ratings_with_books=ratings.merge(books,on='isbn')

# %%
ratings_with_books.shape
# Out:
# (446881, 7)

# %%
ratings_with_books.columns
# Out:
# Index(['user_id', 'isbn', 'rating', 'title', 'author', 'year', 'publisher'], dtype='object')

# %%
number_rating=ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_rating.rename(columns={'number of rating':'number of ratings'},inplace=True)

# %%
number_rating.head()
# Out:
#                                                title  number of ratings
# 0   A Light in the Storm: The Civil War Diary of ...                  2
# 1                              Always Have Popsicles                  1
# 2               Apple Magic (The Collector's series)                  1
# 3   Beyond IBM: Leadership Marketing and Finance ...                  1
# 4   Clifford Visita El Hospital (Clifford El Gran...                  1

# %%
final_rating=ratings_with_books.merge(number_rating,on='title')

# %%
final_rating
# Out:
#         user_id        isbn  rating  \
# 0        277427  002542730X      10
# 1        277427    26217457       0
# 2        277427  003008685X       8
# 3        277427    30615321       0
# 4        277427    60002050       0
# ...         ...         ...     ...
# 446876   250764   451410777       0
# 446877   250764   452264464       8
# 446878   250764  048623715X       0
# 446879   250764   486256588       0
# 446880   250764   515069434       0
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1                      Vegetarian Times Complete Cookbook
# 2                                                Pioneers
# 3        Ask for May, Settle for June (A Doonesbury book)
# 4                       On a Wicked Dawn (Cynster Novels)
# ...                                                   ...
# 446876                            Sleep Tight (Onyx Book)
# ...

# %%
final_rating=final_rating[final_rating['number of ratings']>=50]

# %%
final_rating.shape
# Out:
# (50851, 8)

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)
# Out:
# C:\Users\Ronit Jariwala\AppData\Local\Temp\ipykernel_4144\1573401051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating
# Out:
#         user_id        isbn  rating  \
# 0        277427  002542730X      10
# 13       277427    60930535       0
# 15       277427    60934417       0
# 18       277427    61009059       9
# 24       277427  006440188X       0
# ...         ...         ...     ...
# 446855   250764   449907481       0
# 446862   250764   451180410       0
# 446864   250764   451191013       0
# 446866   250764   451192001       0
# 446877   250764   452264464       8
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 13                          The Poisonwood Bible: A Novel
# 15                                     Bel Canto: A Novel
# 18      One for the Money (Stephanie Plum Novels (Pape...
# 24                                      The Secret Garden
# ...                                                   ...
# 446855      A Thousand Acres (Ballantine Reader's Circle)
# ...

# %%
book_pivot=final_rating.pivot_table(columns='user_id',index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %% [markdown]
#  use nearest neighbours as we have to do clustering it will cluster based on distance closed will be put in one cluster

# %%
from scipy.sparse import csr_matrix
book_sparse=csr_matrix(book_pivot)

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
distances,suggestions=model.kneighbors(book_pivot.iloc[43,:].values.reshape(1,-1),n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 42.82522621, 44.12482295, 44.19275959, 44.20407221,
#         44.36214603]])

# %%
suggestions
# Out:
# array([[ 43, 331, 448, 616,   8,  80]], dtype=int64)

# %%
for i in range(len(suggestions)):
    print(book_pivot.index[suggestions[i]])
# Out:
# Index(['Animal Farm', 'Pleading Guilty', 'The Cradle Will Fall', 'Winter Moon',
#        'A Civil Action', 'CAT'S EYE'],
#       dtype='object', name='title')

# %%
book_pivot.index[43]
# Out:
# 'Animal Farm'

# %% [markdown]
# Create a function to find the recommender

# %%
def recommend_book(book_name):
    book_id=np.where(book_pivot.index==book_name)[0][0]
    distances,suggestions=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)

    for i in range(len(suggestions)):
        if i==0:
            print("The suggestions for",book_name,"are :")
        if not i:
            print(book_pivot.index[suggestions[i]])

# %%
recommend_book('Animal Farm')
# Out:
# The suggestions for Animal Farm are :
# Index(['Animal Farm', 'Pleading Guilty', 'The Cradle Will Fall', 'Winter Moon',
#        'A Civil Action', 'CAT'S EYE'],
#       dtype='object', name='title')
